# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt

# %%
gp=pd.read_csv("googleplaystore.csv")
gp.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#     Reviews    Installs  Type Price Content Rating                     Genres  \
# 0     159.0     10000.0  Free     0       Everyone               Art & Design
# 1     967.0    500000.0  Free     0       Everyone  Art & Design;Pretend Play
# 2   87510.0   5000000.0  Free     0       Everyone               Art & Design
# 3  215644.0  50000000.0  Free     0           Teen               Art & Design
# 4     967.0    100000.0  Free     0       Everyone    Art & Design;Creativity
# 5     167.0     50000.0  Free     0       Everyone               Art & Design
# 6     178.0     50000.0  Free     0       Everyone               Art & Design
# 7   36815.0   1000000.0  Free     0       Everyone               Art & Design
# 8   13791.0   1000000.0  Free     0       Everyone               Art & Design
# 9     121.0     10000.0  Free     0       Everyone    Art & Design;Creativity
#
#          Last Updated         Current Ver   Android Ver
# 0     January 7, 2018               1.0.0  4.0.3 and up
# 1    January 15, 2018               2.0.0  4.0.3 and up
# 2      August 1, 2018               1.2.4  4.0.3 and up
# 3        June 8, 2018  Varies with device    4.2 and up
# 4       June 20, 2018                 1.1    4.4 and up
# 5      March 26, 2017                   1    2.3 and up
# 6      April 26, 2018                 1.1  4.0.3 and up
# 7       June 14, 2018            6.1.61.1    4.2 and up
# 8  September 20, 2017               2.9.2    3.0 and up
# 9        July 3, 2018                 2.8  4.0.3 and up

# %%
gp['Reviews']=gp['Reviews'].ffill()
gp['Installs']=gp['Installs'].ffill()

# %%
print(len('Reviews'))
# Out:
# 7

# %%
x=gp[['Reviews']]
y=gp['Installs']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(len(x_test))
# Out:
# 1820

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [ 8760790.51184102  7567546.61347088  8760790.51184102 ...
#  10451088.5233422   8760790.51184102  8760790.51184102]

# %%
r2 = r2_score(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(r2)
print(mse)
# Out:
# 0.3934227704375034
# 3348722412689290.5

# %%
i
